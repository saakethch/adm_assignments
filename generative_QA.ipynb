# %%
import openai

# get API key from top-right dropdown on OpenAI website
openai.api_key = "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"

query = "who was the 12th person on the moon and when did they land?"

def complete(prompt):
    # query text-davinci-003
    res = openai.Completion.create(
        engine='text-davinci-002',
        prompt=prompt,
        temperature=0,
        max_tokens=400,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    return res['choices'][0]['text'].strip()

query = (
    "Which training method should I use for sentence transformers when " +
    "I only have pairs of related sentences?"
)

print(complete(query))

embed_model = "text-embedding-ada-002"

res = openai.Embedding.create(
    input=[
        "Sample document text goes here",
        "there will be several phrases in each batch"
    ], engine=embed_model
)
res.keys()
len(res['data'])
# Out:
# If you only have pairs of related sentences, you should use the pairwise training method.
# 2

# %%
from youtube_transcript_api import YouTubeTranscriptApi

from datasets import load_dataset
video_ids = [
    "pSdKnNj7ozk",
    "_3-rscgRsYM&t=2s,
    "tmGDx9hVWwo&t=11s",
    "D8ft1stIlCY"
]
data_transcripts = []
for vid_id in video_ids:
    
    data_transcripts.append(YouTubeTranscriptApi.get_transcript(vid_id))
    # except:
    #     pass
# data = load_dataset('jamescalam/youtube-transcriptions', split='train')
data_transcripts
# Out:
# [[{'text': 'all right so this is the new 13-inch m2',
#    'start': 4.56,
#    'duration': 6.159},
#   {'text': "macbook pro and i don't think anyone",
#    'start': 8.24,
#    'duration': 5.279},
#   {'text': 'should actually buy it wait what yeah no',
#    'start': 10.719,
#    'duration': 4.561},
#   {'text': "i think it's a great computer first of",
#    'start': 13.519,
#    'duration': 3.201},
#   {'text': "all don't get me wrong but with the",
#    'start': 15.28,
#    'duration': 4.079},
#   {'text': 'introduction of the m2 macbook air and',
#    'start': 16.72,
#    'duration': 5.6},
#   {'text': 'the existence of the 14-inch m1 pro',
#    'start': 19.359,
#    'duration': 5.68},
#   {'text': "macbook pro they've managed to squeeze",
#    'start': 22.32,
#    'duration': 5.039},
#   {'text': 'any reason for this machine to exist at',
#    'start': 25.039,
#    'duration': 3.441},
#   {'text': 'this price', 'start': 27.359, 'duration': 3.201},
# ...

# %%
texts = []
for data in data_transcripts:
    text = ''
    for timestamps  in data:
        text += " " +  timestamps['text']
    texts.append(text)
texts
# Out:
# ["all right so this is the new 13-inch m2macbook pro and i don't think anyoneshould actually buy it wait what yeah noi think it's a great computer first ofall don't get me wrong but with theintroduction of the m2 macbook air andthe existence of the 14-inch m1 promacbook pro they've managed to squeezeany reason for this machine to exist atthis priceto basically zero nobody should buy ityeah but nobody that i mean that seemspretty harsh matter of fact i'm here letme challenge you on thatthis is a great computer changed my mindokay well let's just start with thedesign so apple's been going throughtheir laptop lineup upgrading everythingwith this new square shape largerdisplays with thinner bezels getting ridof the touch bar and actually addingports but this particular refresh didn'tget any of that so this brand new laptoplooks exactly the same as the m1 macbookpro from two years ago which looksexactly the same as the 13-inch intelmacbook pro with the touch bar thatdropped in 2016 becaus
# ...

# %%
v1 = {'start': 0.0,
 'end': 464.00,
 'title': 'M2 MacBook Pro: Why Does This Exist?',
 'text': texts[0],
 'id': 'pSdKnNj7ozk',
 'url': 'https://youtu.be/pSdKnNj7ozk',
 'published': '2022-07-08 13:00:03 UTC',
 'channel_id': 'UCBJycsmduvYEL83R_U4JriQ'}
v2 = {'start': 0.0,
 'end': 398.00,
 'title': 'M2 MacBook Pro Review (2022)',
 'text': texts[1],
 'id': '_3-rscgRsYM&t=2s',
 'url': 'https://youtu.be/_3-rscgRsYM&t=2s',
 'published': '2022-07-24 13:00:03 UTC',
 'channel_id': 'UCBJycsmduvYEL83R_U4JriQ'}
v3 = {'start': 0.0,
 'end': 562.00,
 'title': 'M2 Max MacBook Pro Review: Back to Bumps!',
 'text': texts[2],
 'id': 'tmGDx9hVWwo&t=11s',
 'url': 'https://youtu.be/tmGDx9hVWwo&t=11s',
 'published': '2023-01-23 13:00:03 UTC',
 'channel_id': 'UCBJycsmduvYEL83R_U4JriQ'}
v4 = {'start': 0.0,
 'end': 840.00,
 'title': 'Which MacBook Should You Buy in 2023? (Avoid These Ones)',
 'text': texts[3],
 'id': 'D8ft1stIlCY',
 'url': 'https://www.youtube.com/watch?v=D8ft1stIlCY',
 'published': '2022-08-09 13:00:03 UTC',
 'channel_id': 'UCBJycsmduvYEL83R_U4JriQ'}

# %%
# from tqdm.auto import tqdm

# new_data = []

# window = 20  # number of sentences to combine
# stride = 4  # number of sentences to 'stride' over, used to create overlap

# for i in tqdm(range(0, len(data), stride)):
#     i_end = min(len(data)-1, i+window)
#     if data[i]['title'] != data[i_end]['title']:
#         # in this case we skip this entry as we have start/end of two videos
#         continue
#     text = ' '.join(data[i:i_end]['text'])
#     # create the new merged dataset
#     new_data.append({
#         'start': data[i]['start'],
#         'end': data[i_end]['end'],
#         'title': data[i]['title'],
#         'text': text,
#         'id': data[i]['id'],
#         'url': data[i]['url'],
#         'published': data[i]['published'],
#         'channel_id': data[i]['channel_id']
#     })
new_data = [v1,v2,v3,v4]

# %%
new_data[0]
# Out:
# {'start': 0.0,
#  'end': 464.0,
#  'title': 'M2 MacBook Pro: Why Does This Exist?',
# ...

# %%
len(data)
# Out:
# 208619

# %%
len(new_data)
# Out:
# 4

# %%
import pinecone

index_name = 'openai-youtube-mac-transcriptions-a5'

# initialize connection to pinecone (get API key at app.pinecone.io)
pinecone.init(
    api_key="cd5700c8-f94e-4688-94ee-20c4c451d36b",
    environment="northamerica-northeast1-gcp"
)

# check if index already exists (it shouldn't if this is first time)
if index_name not in pinecone.list_indexes():
    # if does not exist, create index
    pinecone.create_index(
        index_name,
        dimension=len(res['data'][0]['embedding']),
        metric='cosine',
        metadata_config={'indexed': ['channel_id', 'published']}
    )
# connect to index
index = pinecone.Index(index_name)
# view index stats

# %%
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
from tqdm.auto import tqdm
import datetime
from time import sleep

batch_size = 100  # how many embeddings we create and insert at once

for i in tqdm(range(0, len(new_data)//2, batch_size)):
    # find end of batch
    i_end = min(len(new_data), i+batch_size)
    meta_batch = new_data[i:i_end]
    # get ids
    ids_batch = [x['id'] for x in meta_batch]
    # get texts to encode
    texts = [x['text'] for x in meta_batch]
    # create embeddings (try-except added to avoid RateLimitError)
    try:
        res = openai.Embedding.create(input=texts, engine=embed_model)
    except:
        done = False
        while not done:
            sleep(5)
            try:
                res = openai.Embedding.create(input=texts, engine=embed_model)
                done = True
            except:
                pass
    embeds = [record['embedding'] for record in res['data']]
    # cleanup metadata
    meta_batch = [{
        'start': x['start'],
        'end': x['end'],
        'title': x['title'],
        'text': x['text'],
        'url': x['url'],
        'published': x['published'],
        'channel_id': x['channel_id']
    } for x in meta_batch]
    to_upsert = list(zip(ids_batch, embeds, meta_batch))
    # upsert to Pinecone
    index.upsert(vectors=to_upsert)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
res = openai.Embedding.create(
    input=[query],
    engine=embed_model
)

# retrieve from Pinecone
xq = res['data'][0]['embedding']

# get relevant contexts (including the questions)
res = index.query(xq, top_k=2, include_metadata=True)

# %%
limit = 3750

def retrieve(query):
    res = openai.Embedding.create(
        input=[query],
        engine=embed_model
    )

    # retrieve from Pinecone
    xq = res['data'][0]['embedding']

    # get relevant contexts
    res = index.query(xq, top_k=3, include_metadata=True)
    contexts = [
        x['metadata']['text'] for x in res['matches']
    ]

    # build our prompt with the retrieved contexts included
    prompt_start = (
        "Answer the question based on the context below.\n\n"+
        "Context:\n"
    )
    prompt_end = (
        f"\n\nQuestion: {query}\nAnswer:"
    )
    # append contexts until hitting limit
    for i in range(1, len(contexts)):
        if len("\n\n---\n\n".join(contexts[:i])) >= limit:
            prompt = (
                prompt_start +
                "\n\n---\n\n".join(contexts[:i-1]) +
                prompt_end
            )
            break
        elif i == len(contexts)-1:
            prompt = (
                prompt_start +
                "\n\n---\n\n".join(contexts) +
                prompt_end
            )
    return prompt

# %%
# first we retrieve relevant items from Pinecone

# %%
# then we complete the context-infused query

# %%
def ask_me(prompt):
    query = prompt
    query_with_contexts = retrieve(query)
    query_with_contexts
    return complete(query_with_contexts)

# %%
ask_me("Does it have a bright display if so how many nits")
# Out:
# 'Yes, the display is bright with a peak brightness of 1,000 nits.'
